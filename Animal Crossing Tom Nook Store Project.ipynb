# %% [markdown]
# # Animal Crossing Tom Nook Store Project

# %% [markdown]
# ### URL for Source Below

# %% [markdown]
# https://www.kaggle.com/code/ampiiere/animal-crossing-villager-popularity-analysis/notebook

# %% [markdown]
# https://www.kaggle.com/datasets/prasertk/animal-crossing-new-horizons-with-image-url

# %% [markdown]
# # Introduction

# %%
# Tom Nook, a known Animal Crossing character who is a Retail Store Owner, wants to get know his target audience. 
# Tom nook sells Accessories, Furniture, Wallpaper, Flooring, Gardening supplies, and seasonal items
# He is planning on future furniture purchases for retail value but wants to coordinate the purchases based on demand 
# He needs your help to analyze the lifestyles, purchase histories, species, gender, etc. of these villagers 
# This information will also help him to maintain his competitive edge against competitors like Crazy Redd and Saharah.
# Keep in mind the currency used in Animal Crossing are Bells

# %%
# Carlos - note: Making furniture purchases based on the demand of the villagers 
# will have to also come from what the villagers have previously purchased too
# I don't have access to Furniture or other revenue nor company expenditures data
# I notice the villagers have wallpapers and floors. 
# We should base furniture purchases based on the wallpaper and floor purchases sold by Tom Nook
# Our goal is to consult what complementary furniture to sell 
# There is a possibility that The villagers ideals are to buy furniture relevant to the interior design

# %%
import numpy as np  # data processing
import matplotlib.pyplot as plt # Data visualization library
import seaborn as sns # Data visualization library
import pandas as pd # read files and data processing

# %%
vlgr_df=pd.read_csv(r"C:\Users\carlo\OneDrive\Documents\My Data Analytics Projects\Animal Crossing\Animal Crossing Tom Nook Business Project\Raw Data\villagers (1).csv")

# %%
vlgr_df
# Out:
#          Name    Species  Gender Personality      Hobby Birthday Catchphrase  \
# 0     Admiral       Bird    Male      Cranky     Nature   27-Jan     aye aye
# 1     Agent S   Squirrel  Female       Peppy    Fitness    2-Jul    sidekick
# 2       Agnes        Pig  Female  Big Sister       Play   21-Apr     snuffle
# 3          Al    Gorilla    Male        Lazy    Fitness   18-Oct     ayyyeee
# 4     Alfonso  Alligator    Male        Lazy       Play    9-Jun    it'sa me
# ..        ...        ...     ...         ...        ...      ...         ...
# 386    Winnie      Horse  Female       Peppy    Fashion   31-Jan      hay-OK
# 387  Wolfgang       Wolf    Male      Cranky  Education   25-Nov     snarrrl
# 388      Yuka      Koala  Female      Snooty    Fashion   20-Jul     tsk tsk
# 389      Zell       Deer    Male        Smug      Music    7-Jun       pronk
# 390    Zucker    Octopus    Male        Lazy     Nature    8-Mar       bloop
#
#        Favorite Song Style 1   Style 2 Color 1 Color 2  \
# 0         Steep Hill    Cool      Cool   Black    Blue
# 1      Go K.K. Rider  Active    Simple    Blue   Black
# 2         K.K. House  Simple   Elegant    Pink   White
# 3      Go K.K. Rider  Active    Active     Red   White
# 4        Forest Life  Simple    Simple     Red    Blue
# ..               ...     ...       ...     ...     ...
# 386     K.K. Country    Cool    Simple   White    Gray
# 387         K.K. D&B    Cool    Active   Black   Green
# 388     Soulful K.K.    Cool   Elegant  Orange  Yellow
# 389       K.K. Swing    Cool  Gorgeous  Purple    Gray
# 390  Spring Blossoms  Simple      Cute    Blue  Yellow
#
#                    Wallpaper                     Flooring  \
# 0             dirt-clod wall                       tatami
# 1              concrete wall       colorful tile flooring
# 2     gray molded-panel wall           arabesque flooring
# 3              concrete wall        green rubber flooring
# 4       yellow playroom wall         green honeycomb tile
# ..                       ...                          ...
# 386      backyard-fence wall                backyard lawn
# 387  dark wooden-mosaic wall              stripe flooring
# 388      beige art-deco wall       simple purple flooring
# 389           cityscape wall  monochromatic tile flooring
# 390         chain-link fence                backyard lawn
#
#                                         Furniture List Filename  \
# 0    717;1849;7047;2736;787;5970;3449;3622;3802;410...    brd06
# 1    7845;7150;3468;4080;290;3971;3449;1708;4756;25...    squ05
# 2    4129;7236;7235;7802;896;3428;4027;7325;3958;71...    pig17
# 3    1452;4078;4013;833;4116;3697;7845;3307;3946;39...    gor08
# 4    4763;3205;3701;1557;3623;85;3208;3584;4761;121...    crd00
# ..                                                 ...      ...
# 386  1626;1626;5970;4003;3509;1620;1627;3467;1631;1...    hrs05
# 387  4117;7323;7323;3275;4109;3270;3196;4338;3200;3...    wol02
# 388    3957;3955;2554;3974;3951;794;4106;3959;3958;997    kal00
# 389  1875;863;4129;4053;4053;3951;794;3775;4046;423...    der02
# 390  4042;4412;7526;4077;4077;3064;4077;3946;3617;3...    ocp02
#
#        Unique Entry ID
# 0    B3RyfNEqwGmcccRC3
# 1    SGMdki6dzpDZyXAw5
# 2    jzWCiDPm9MqtCfecP
# 3    LBifxETQJGEaLhBjC
# 4    REpd8KxB8p9aGBRSE
# ..                 ...
# 386  b4HwfyvThyipScSAv
# 387  RbF2wcn6jRxtgLDRd
# 388  QDcxk3dCNT6yeD9hk
# 389  LodBWtdMRZbjFNga9
# 390  2F5tipHqgmWvWXTLC
#
# [391 rows x 17 columns]

# %%
wallpaper_df=pd.read_csv(r"C:\Users\carlo\OneDrive\Documents\My Data Analytics Projects\Animal Crossing\Animal Crossing Tom Nook Business Project\Raw Data\wallpaper.csv")

# %%
wallpaper_df
# Out:
#                          Name  VFX VFX Type  DIY   Buy    Sell     Color 1  \
# 0               abstract wall   No      NaN   No  1560   390.0       White
# 1                ancient wall   No      NaN   No  3000   750.0       Beige
# 2                  apple wall   No      NaN  Yes   NFS  4000.0         Red
# 3              aqua tile wall   No      NaN   No  1420   355.0  Light blue
# 4          arched-window wall  Yes      NaN   No  2150   537.0       Brown
# ..                        ...  ...      ...  ...   ...     ...         ...
# 242      yellow playroom wall   No      NaN   No  2540   635.0      Yellow
# 243         yellow quilt wall   No      NaN   No  2150   537.0      Yellow
# 244  yellow simple-cloth wall   No      NaN   No   750   187.0       Beige
# 245         yellow-paint wall   No      NaN   No  1600   400.0      Yellow
# 246       yellow-striped wall   No      NaN   No  1520   380.0      Yellow
#
#         Color 2  Miles Price         Source  ...  Curtain Color Ceiling Type  \
# 0      Colorful          NaN  Nook's Cranny  ...          White        Cloth
# 1         Brown          NaN        Saharah  ...            NaN        Stone
# 2           Red          NaN       Crafting  ...          White        Cloth
# 3    Light blue          NaN  Nook's Cranny  ...  White Plastic        Stone
# 4    Light blue          NaN  Nook's Cranny  ...            NaN         Wood
# ..          ...          ...            ...  ...            ...          ...
# 242      Yellow          NaN  Nook's Cranny  ...            NaN        Cloth
# 243       White          NaN  Nook's Cranny  ...     White Lace         Wood
# 244      Yellow          NaN  Nook's Cranny  ...          White        Stone
# 245      Yellow          NaN  Nook's Cranny  ...            NaN        Cloth
# 246       Beige          NaN  Nook's Cranny  ...          White        Cloth
#
#     HHA Concept 1 HHA Concept 2 HHA Series              Tag Version  \
# 0            shop      facility       None      Cloth Walls   1.0.0
# 1        folk art        horror       None             Asia   1.0.0
# 2           fancy  child's room     fruits      Fruit Walls   1.0.0
# 3        bathroom      facility       None       Tile Walls   1.0.0
# 4            shop     expensive       None    Special Walls   1.0.0
# ..            ...           ...        ...              ...     ...
# 242  child's room         fancy       None        Toy Walls   1.0.0
# 243         fancy  child's room       None  Dollhouse Walls   1.0.0
# 244  child's room   living room       None     Simple Walls   1.0.0
# 245         fancy  child's room       None     Stucco Walls   1.0.0
# 246         fancy  child's room       None     Stripe Walls   1.0.0
#
#                    Filename Internal ID    Unique Entry ID
# 0     RoomTexWallAbstract00        4873  FpdbDr4PMe5WdEZkA
# 1        RoomTexWallEgypt00        4936  Y2pykQMhqbEoGGa62
# 2        RoomTexWallApple00        4916  roJZFWataeLQK6vqa
# 3         RoomTexWallTile01        4930  6NXvjsdpxJLbd96RM
# 4         RoomSpWallGlass00        5482  TzS5oe6a7KyBezmLS
# ..                      ...         ...                ...
# 242        RoomTexWallToy03        6865  mraytANoYBQvA8qAk
# 243  RoomTexWallDollhouse02        7276  ysEdh2vpCpg5qBcNg
# 244     RoomTexWallSimple01        4867  7sSXFNqcYgPMcGY8k
# 245     RoomTexWallStucco00        4808  TySAA4kKqyvGGeZ5C
# 246     RoomTexWallStripe04        4946  N6sef3YhY973LDgdR
#
# [247 rows x 26 columns]

# %%
wallpaper_df=wallpaper_df.rename(columns={'Name':'Wallpaper'})

# %%
wallpaper_df
# Out:
#                     Wallpaper  VFX VFX Type  DIY   Buy    Sell     Color 1  \
# 0               abstract wall   No      NaN   No  1560   390.0       White
# 1                ancient wall   No      NaN   No  3000   750.0       Beige
# 2                  apple wall   No      NaN  Yes   NFS  4000.0         Red
# 3              aqua tile wall   No      NaN   No  1420   355.0  Light blue
# 4          arched-window wall  Yes      NaN   No  2150   537.0       Brown
# ..                        ...  ...      ...  ...   ...     ...         ...
# 242      yellow playroom wall   No      NaN   No  2540   635.0      Yellow
# 243         yellow quilt wall   No      NaN   No  2150   537.0      Yellow
# 244  yellow simple-cloth wall   No      NaN   No   750   187.0       Beige
# 245         yellow-paint wall   No      NaN   No  1600   400.0      Yellow
# 246       yellow-striped wall   No      NaN   No  1520   380.0      Yellow
#
#         Color 2  Miles Price         Source  ...  Curtain Color Ceiling Type  \
# 0      Colorful          NaN  Nook's Cranny  ...          White        Cloth
# 1         Brown          NaN        Saharah  ...            NaN        Stone
# 2           Red          NaN       Crafting  ...          White        Cloth
# 3    Light blue          NaN  Nook's Cranny  ...  White Plastic        Stone
# 4    Light blue          NaN  Nook's Cranny  ...            NaN         Wood
# ..          ...          ...            ...  ...            ...          ...
# 242      Yellow          NaN  Nook's Cranny  ...            NaN        Cloth
# 243       White          NaN  Nook's Cranny  ...     White Lace         Wood
# 244      Yellow          NaN  Nook's Cranny  ...          White        Stone
# 245      Yellow          NaN  Nook's Cranny  ...            NaN        Cloth
# 246       Beige          NaN  Nook's Cranny  ...          White        Cloth
#
#     HHA Concept 1 HHA Concept 2 HHA Series              Tag Version  \
# 0            shop      facility       None      Cloth Walls   1.0.0
# 1        folk art        horror       None             Asia   1.0.0
# 2           fancy  child's room     fruits      Fruit Walls   1.0.0
# 3        bathroom      facility       None       Tile Walls   1.0.0
# 4            shop     expensive       None    Special Walls   1.0.0
# ..            ...           ...        ...              ...     ...
# 242  child's room         fancy       None        Toy Walls   1.0.0
# 243         fancy  child's room       None  Dollhouse Walls   1.0.0
# 244  child's room   living room       None     Simple Walls   1.0.0
# 245         fancy  child's room       None     Stucco Walls   1.0.0
# 246         fancy  child's room       None     Stripe Walls   1.0.0
#
#                    Filename Internal ID    Unique Entry ID
# 0     RoomTexWallAbstract00        4873  FpdbDr4PMe5WdEZkA
# 1        RoomTexWallEgypt00        4936  Y2pykQMhqbEoGGa62
# 2        RoomTexWallApple00        4916  roJZFWataeLQK6vqa
# 3         RoomTexWallTile01        4930  6NXvjsdpxJLbd96RM
# 4         RoomSpWallGlass00        5482  TzS5oe6a7KyBezmLS
# ..                      ...         ...                ...
# 242        RoomTexWallToy03        6865  mraytANoYBQvA8qAk
# 243  RoomTexWallDollhouse02        7276  ysEdh2vpCpg5qBcNg
# 244     RoomTexWallSimple01        4867  7sSXFNqcYgPMcGY8k
# 245     RoomTexWallStucco00        4808  TySAA4kKqyvGGeZ5C
# 246     RoomTexWallStripe04        4946  N6sef3YhY973LDgdR
#
# [247 rows x 26 columns]

# %%
flooring_df=pd.read_csv(r"C:\Users\carlo\OneDrive\Documents\My Data Analytics Projects\Animal Crossing\Animal Crossing Tom Nook Business Project\Raw Data\floors.csv")

# %%
flooring_df=flooring_df.rename(columns={'Name':'Flooring'})

# %%
flooring_df
# Out:
#                    Flooring VFX DIY   Buy  Sell     Color 1     Color 2  \
# 0        aqua tile flooring  No  No   900   225  Light blue  Light blue
# 1        arabesque flooring  No  No  2120   530       Black        Gray
# 2     arched-brick flooring  No  No  1100   275       Brown       Brown
# 3      argyle tile flooring  No  No  1750   437       White       Beige
# 4    artsy parquet flooring  No  No  1800   450       Beige       Beige
# ..                      ...  ..  ..   ...   ...         ...         ...
# 171    white-paint flooring  No  No  1040   260       White       White
# 172       wildflower meadow  No  No  3000   750       Green       Green
# 173    wooden-knot flooring  No  No   780   195       Brown       Brown
# 174  yellow floral flooring  No  No  1520   380      Yellow      Yellow
# 175    zebra-print flooring  No  No  1300   325       Black       White
#
#      Miles Price         Source  Source Notes Version HHA Concept 1  \
# 0            NaN  Nook's Cranny           NaN   1.0.0      bathroom
# 1            NaN  Nook's Cranny           NaN   1.0.0     expensive
# 2            NaN  Nook's Cranny           NaN   1.0.0      facility
# 3            NaN  Nook's Cranny           NaN   1.0.0      bathroom
# 4            NaN  Nook's Cranny           NaN   1.0.0      facility
# ..           ...            ...           ...     ...           ...
# 171          NaN  Nook's Cranny           NaN   1.0.0   living room
# 172          NaN        Saharah           NaN   1.0.0        garden
# 173          NaN  Nook's Cranny           NaN   1.0.0   living room
# 174          NaN  Nook's Cranny           NaN   1.0.0          shop
# 175          NaN  Nook's Cranny           NaN   1.0.0         party
#
#     HHA Concept 2 HHA Series             Tag       Catalog  \
# 0        facility       None     Tile Floors      For sale
# 1     living room       None    Cloth Floors      For sale
# 2            shop       None    Arched Brick      For sale
# 3        facility       None     Tile Floors      For sale
# 4            shop       None  Simple Parquet      For sale
# ..            ...        ...             ...           ...
# 171  child's room       None    Painted Wood      For sale
# 172         fancy       None       Grassland  Not for sale
# 173  child's room       None     Wood Floors      For sale
# 174   living room       None       Deco Wood      For sale
# 175         fancy       None    Animal Floor      For sale
#
#                      Filename  Internal ID    Unique Entry ID
# 0          RoomTexFloorTile01         5036  JmNGqRhEow3PH7bgk
# 1     RoomTexFloorArabesque00         4953  4dabyuetmZD5dDdCH
# 2     RoomTexFloorArchBrick00         4998  CSPoYJzCnzWjqWrj5
# 3      RoomTexFloorTileWood00         4994  BH8PqRSou2XjQ8ppQ
# 4    RoomTexFloorParquetArt00         5232  fbfCzw546bWEF95Aq
# ..                        ...          ...                ...
# 171   RoomTexFloorPaintWood03         5060  JdnrGbAMW7FBxrw5P
# 172   RoomTexFloorGrassland01         5006  dYb6DAfZQJTGN7svs
# 173       RoomTexFloorCedar00         5049  ttyLLQ39Dc3fK32JE
# 174    RoomTexFloorDecoWood00         5073  R69sMEPHQGu7fBzuQ
# 175      RoomTexFloorAnimal02         4962  9Mdszd5EgwJ6omLPf
#
# [176 rows x 19 columns]

# %%
vlgr_df.head()
# Out:
#       Name    Species  Gender Personality    Hobby Birthday Catchphrase  \
# 0  Admiral       Bird    Male      Cranky   Nature   27-Jan     aye aye
# 1  Agent S   Squirrel  Female       Peppy  Fitness    2-Jul    sidekick
# 2    Agnes        Pig  Female  Big Sister     Play   21-Apr     snuffle
# 3       Al    Gorilla    Male        Lazy  Fitness   18-Oct     ayyyeee
# 4  Alfonso  Alligator    Male        Lazy     Play    9-Jun    it'sa me
#
#    Favorite Song Style 1  Style 2 Color 1 Color 2               Wallpaper  \
# 0     Steep Hill    Cool     Cool   Black    Blue          dirt-clod wall
# 1  Go K.K. Rider  Active   Simple    Blue   Black           concrete wall
# 2     K.K. House  Simple  Elegant    Pink   White  gray molded-panel wall
# 3  Go K.K. Rider  Active   Active     Red   White           concrete wall
# 4    Forest Life  Simple   Simple     Red    Blue    yellow playroom wall
#
#                  Flooring                                     Furniture List  \
# 0                  tatami  717;1849;7047;2736;787;5970;3449;3622;3802;410...
# 1  colorful tile flooring  7845;7150;3468;4080;290;3971;3449;1708;4756;25...
# 2      arabesque flooring  4129;7236;7235;7802;896;3428;4027;7325;3958;71...
# 3   green rubber flooring  1452;4078;4013;833;4116;3697;7845;3307;3946;39...
# 4    green honeycomb tile  4763;3205;3701;1557;3623;85;3208;3584;4761;121...
#
#   Filename    Unique Entry ID
# 0    brd06  B3RyfNEqwGmcccRC3
# 1    squ05  SGMdki6dzpDZyXAw5
# 2    pig17  jzWCiDPm9MqtCfecP
# 3    gor08  LBifxETQJGEaLhBjC
# 4    crd00  REpd8KxB8p9aGBRSE

# %%
wallpaper_df.head()
# Out:
#             Wallpaper  VFX VFX Type  DIY   Buy    Sell     Color 1  \
# 0       abstract wall   No      NaN   No  1560   390.0       White
# 1        ancient wall   No      NaN   No  3000   750.0       Beige
# 2          apple wall   No      NaN  Yes   NFS  4000.0         Red
# 3      aqua tile wall   No      NaN   No  1420   355.0  Light blue
# 4  arched-window wall  Yes      NaN   No  2150   537.0       Brown
#
#       Color 2  Miles Price         Source  ...  Curtain Color Ceiling Type  \
# 0    Colorful          NaN  Nook's Cranny  ...          White        Cloth
# 1       Brown          NaN        Saharah  ...            NaN        Stone
# 2         Red          NaN       Crafting  ...          White        Cloth
# 3  Light blue          NaN  Nook's Cranny  ...  White Plastic        Stone
# 4  Light blue          NaN  Nook's Cranny  ...            NaN         Wood
#
#   HHA Concept 1 HHA Concept 2 HHA Series            Tag Version  \
# 0          shop      facility       None    Cloth Walls   1.0.0
# 1      folk art        horror       None           Asia   1.0.0
# 2         fancy  child's room     fruits    Fruit Walls   1.0.0
# 3      bathroom      facility       None     Tile Walls   1.0.0
# 4          shop     expensive       None  Special Walls   1.0.0
#
#                 Filename Internal ID    Unique Entry ID
# 0  RoomTexWallAbstract00        4873  FpdbDr4PMe5WdEZkA
# 1     RoomTexWallEgypt00        4936  Y2pykQMhqbEoGGa62
# 2     RoomTexWallApple00        4916  roJZFWataeLQK6vqa
# 3      RoomTexWallTile01        4930  6NXvjsdpxJLbd96RM
# 4      RoomSpWallGlass00        5482  TzS5oe6a7KyBezmLS
#
# [5 rows x 26 columns]

# %%
flooring_df.head()
# Out:
#                  Flooring VFX DIY   Buy  Sell     Color 1     Color 2  \
# 0      aqua tile flooring  No  No   900   225  Light blue  Light blue
# 1      arabesque flooring  No  No  2120   530       Black        Gray
# 2   arched-brick flooring  No  No  1100   275       Brown       Brown
# 3    argyle tile flooring  No  No  1750   437       White       Beige
# 4  artsy parquet flooring  No  No  1800   450       Beige       Beige
#
#    Miles Price         Source  Source Notes Version HHA Concept 1  \
# 0          NaN  Nook's Cranny           NaN   1.0.0      bathroom
# 1          NaN  Nook's Cranny           NaN   1.0.0     expensive
# 2          NaN  Nook's Cranny           NaN   1.0.0      facility
# 3          NaN  Nook's Cranny           NaN   1.0.0      bathroom
# 4          NaN  Nook's Cranny           NaN   1.0.0      facility
#
#   HHA Concept 2 HHA Series             Tag   Catalog  \
# 0      facility       None     Tile Floors  For sale
# 1   living room       None    Cloth Floors  For sale
# 2          shop       None    Arched Brick  For sale
# 3      facility       None     Tile Floors  For sale
# 4          shop       None  Simple Parquet  For sale
#
#                    Filename  Internal ID    Unique Entry ID
# 0        RoomTexFloorTile01         5036  JmNGqRhEow3PH7bgk
# 1   RoomTexFloorArabesque00         4953  4dabyuetmZD5dDdCH
# 2   RoomTexFloorArchBrick00         4998  CSPoYJzCnzWjqWrj5
# 3    RoomTexFloorTileWood00         4994  BH8PqRSou2XjQ8ppQ
# 4  RoomTexFloorParquetArt00         5232  fbfCzw546bWEF95Aq

# %% [markdown]
# ## 1. Checking for Null values

# %%
vlgr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             391 non-null    object
#  1   Species          391 non-null    object
#  2   Gender           391 non-null    object
#  3   Personality      391 non-null    object
#  4   Hobby            391 non-null    object
#  5   Birthday         391 non-null    object
#  6   Catchphrase      391 non-null    object
#  7   Favorite Song    391 non-null    object
#  8   Style 1          391 non-null    object
#  9   Style 2          391 non-null    object
#  10  Color 1          391 non-null    object
#  11  Color 2          391 non-null    object
#  12  Wallpaper        391 non-null    object
#  13  Flooring         391 non-null    object
#  14  Furniture List   391 non-null    object
#  15  Filename         391 non-null    object
#  16  Unique Entry ID  391 non-null    object
# dtypes: object(17)
# memory usage: 52.1+ KB

# %%
wallpaper_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Wallpaper        247 non-null    object
#  1   VFX              247 non-null    object
#  2   VFX Type         25 non-null     object
#  3   DIY              247 non-null    object
#  4   Buy              247 non-null    object
#  5   Sell             247 non-null    float64
#  6   Color 1          247 non-null    object
#  7   Color 2          247 non-null    object
#  8   Miles Price      1 non-null      float64
#  9   Source           247 non-null    object
#  10  Source Notes     0 non-null      float64
#  11  Catalog          247 non-null    object
#  12  Window Type      247 non-null    object
#  13  Window Color     147 non-null    object
#  14  Pane Type        147 non-null    object
#  15  Curtain Type     247 non-null    object
#  16  Curtain Color    98 non-null     object
#  17  Ceiling Type     247 non-null    object
#  18  HHA Concept 1    247 non-null    object
#  19  HHA Concept 2    247 non-null    object
#  20  HHA Series       247 non-null    object
#  21  Tag              247 non-null    object
#  22  Version          247 non-null    object
#  23  Filename         247 non-null    object
#  24  Internal ID      247 non-null    int64
#  25  Unique Entry ID  247 non-null    object
# dtypes: float64(3), int64(1), object(22)
# memory usage: 50.3+ KB

# %%
flooring_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Flooring         176 non-null    object
#  1   VFX              173 non-null    object
#  2   DIY              176 non-null    object
#  3   Buy              176 non-null    object
#  4   Sell             176 non-null    int64
#  5   Color 1          176 non-null    object
#  6   Color 2          176 non-null    object
#  7   Miles Price      1 non-null      float64
#  8   Source           176 non-null    object
#  9   Source Notes     0 non-null      float64
#  10  Version          176 non-null    object
#  11  HHA Concept 1    176 non-null    object
#  12  HHA Concept 2    176 non-null    object
#  13  HHA Series       176 non-null    object
#  14  Tag              176 non-null    object
#  15  Catalog          176 non-null    object
#  16  Filename         176 non-null    object
#  17  Internal ID      176 non-null    int64
#  18  Unique Entry ID  176 non-null    object
# dtypes: float64(2), int64(2), object(15)
# memory usage: 26.2+ KB

# %% [markdown]
# ## 2. Checking for mismatched names

# %%
wallpaper_df['Wallpaper'].isin(vlgr_df['Wallpaper']).sum()
# Out:
# 154

# %%
flooring_df['Flooring'].isin(vlgr_df['Flooring']).sum()
# Out:
# 128

# %%
# checking for any wallpaper information left out of the villager dataset

mismatch_wallpaper = vlgr_df['Wallpaper'][vlgr_df['Wallpaper'].isin(wallpaper_df['Wallpaper'])==False]

# %%
# All information correlated to villagers are present

mismatch_wallpaper
# Out:
# Series([], Name: Wallpaper, dtype: object)

# %%
# checking for any flooring information left out of the villager dataset

mismatch_flooring = vlgr_df['Flooring'][vlgr_df['Flooring'].isin(flooring_df['Flooring'])==False]

# %%
# All information correlated to villagers are present. Information verified on excel. Everything is present

mismatch_flooring
# Out:
# Series([], Name: Flooring, dtype: object)

# %%
# drop wallpaper that are in wallpaper_df but not in vlgr_df

# wallpaper_df=wallpaper_df.drop(wallpaper_df[wallpaper_df['Wallpaper_name'].isin(vlgr_df['Wallpaper'])==False].index)

# %%
vlgr_df
# Out:
#          Name    Species  Gender Personality      Hobby Birthday Catchphrase  \
# 0     Admiral       Bird    Male      Cranky     Nature   27-Jan     aye aye
# 1     Agent S   Squirrel  Female       Peppy    Fitness    2-Jul    sidekick
# 2       Agnes        Pig  Female  Big Sister       Play   21-Apr     snuffle
# 3          Al    Gorilla    Male        Lazy    Fitness   18-Oct     ayyyeee
# 4     Alfonso  Alligator    Male        Lazy       Play    9-Jun    it'sa me
# ..        ...        ...     ...         ...        ...      ...         ...
# 386    Winnie      Horse  Female       Peppy    Fashion   31-Jan      hay-OK
# 387  Wolfgang       Wolf    Male      Cranky  Education   25-Nov     snarrrl
# 388      Yuka      Koala  Female      Snooty    Fashion   20-Jul     tsk tsk
# 389      Zell       Deer    Male        Smug      Music    7-Jun       pronk
# 390    Zucker    Octopus    Male        Lazy     Nature    8-Mar       bloop
#
#        Favorite Song Style 1   Style 2 Color 1 Color 2  \
# 0         Steep Hill    Cool      Cool   Black    Blue
# 1      Go K.K. Rider  Active    Simple    Blue   Black
# 2         K.K. House  Simple   Elegant    Pink   White
# 3      Go K.K. Rider  Active    Active     Red   White
# 4        Forest Life  Simple    Simple     Red    Blue
# ..               ...     ...       ...     ...     ...
# 386     K.K. Country    Cool    Simple   White    Gray
# 387         K.K. D&B    Cool    Active   Black   Green
# 388     Soulful K.K.    Cool   Elegant  Orange  Yellow
# 389       K.K. Swing    Cool  Gorgeous  Purple    Gray
# 390  Spring Blossoms  Simple      Cute    Blue  Yellow
#
#                    Wallpaper                     Flooring  \
# 0             dirt-clod wall                       tatami
# 1              concrete wall       colorful tile flooring
# 2     gray molded-panel wall           arabesque flooring
# 3              concrete wall        green rubber flooring
# 4       yellow playroom wall         green honeycomb tile
# ..                       ...                          ...
# 386      backyard-fence wall                backyard lawn
# 387  dark wooden-mosaic wall              stripe flooring
# 388      beige art-deco wall       simple purple flooring
# 389           cityscape wall  monochromatic tile flooring
# 390         chain-link fence                backyard lawn
#
#                                         Furniture List Filename  \
# 0    717;1849;7047;2736;787;5970;3449;3622;3802;410...    brd06
# 1    7845;7150;3468;4080;290;3971;3449;1708;4756;25...    squ05
# 2    4129;7236;7235;7802;896;3428;4027;7325;3958;71...    pig17
# 3    1452;4078;4013;833;4116;3697;7845;3307;3946;39...    gor08
# 4    4763;3205;3701;1557;3623;85;3208;3584;4761;121...    crd00
# ..                                                 ...      ...
# 386  1626;1626;5970;4003;3509;1620;1627;3467;1631;1...    hrs05
# 387  4117;7323;7323;3275;4109;3270;3196;4338;3200;3...    wol02
# 388    3957;3955;2554;3974;3951;794;4106;3959;3958;997    kal00
# 389  1875;863;4129;4053;4053;3951;794;3775;4046;423...    der02
# 390  4042;4412;7526;4077;4077;3064;4077;3946;3617;3...    ocp02
#
#        Unique Entry ID
# 0    B3RyfNEqwGmcccRC3
# 1    SGMdki6dzpDZyXAw5
# 2    jzWCiDPm9MqtCfecP
# 3    LBifxETQJGEaLhBjC
# 4    REpd8KxB8p9aGBRSE
# ..                 ...
# 386  b4HwfyvThyipScSAv
# 387  RbF2wcn6jRxtgLDRd
# 388  QDcxk3dCNT6yeD9hk
# 389  LodBWtdMRZbjFNga9
# 390  2F5tipHqgmWvWXTLC
#
# [391 rows x 17 columns]

# %% [markdown]
# ## 3. Merging the three Dataset (Work in Progress)

# %%
wallpaper_df
# Out:
#                     Wallpaper  VFX VFX Type  DIY   Buy    Sell     Color 1  \
# 0               abstract wall   No      NaN   No  1560   390.0       White
# 1                ancient wall   No      NaN   No  3000   750.0       Beige
# 2                  apple wall   No      NaN  Yes   NFS  4000.0         Red
# 3              aqua tile wall   No      NaN   No  1420   355.0  Light blue
# 4          arched-window wall  Yes      NaN   No  2150   537.0       Brown
# ..                        ...  ...      ...  ...   ...     ...         ...
# 242      yellow playroom wall   No      NaN   No  2540   635.0      Yellow
# 243         yellow quilt wall   No      NaN   No  2150   537.0      Yellow
# 244  yellow simple-cloth wall   No      NaN   No   750   187.0       Beige
# 245         yellow-paint wall   No      NaN   No  1600   400.0      Yellow
# 246       yellow-striped wall   No      NaN   No  1520   380.0      Yellow
#
#         Color 2  Miles Price         Source  ...  Curtain Color Ceiling Type  \
# 0      Colorful          NaN  Nook's Cranny  ...          White        Cloth
# 1         Brown          NaN        Saharah  ...            NaN        Stone
# 2           Red          NaN       Crafting  ...          White        Cloth
# 3    Light blue          NaN  Nook's Cranny  ...  White Plastic        Stone
# 4    Light blue          NaN  Nook's Cranny  ...            NaN         Wood
# ..          ...          ...            ...  ...            ...          ...
# 242      Yellow          NaN  Nook's Cranny  ...            NaN        Cloth
# 243       White          NaN  Nook's Cranny  ...     White Lace         Wood
# 244      Yellow          NaN  Nook's Cranny  ...          White        Stone
# 245      Yellow          NaN  Nook's Cranny  ...            NaN        Cloth
# 246       Beige          NaN  Nook's Cranny  ...          White        Cloth
#
#     HHA Concept 1 HHA Concept 2 HHA Series              Tag Version  \
# 0            shop      facility       None      Cloth Walls   1.0.0
# 1        folk art        horror       None             Asia   1.0.0
# 2           fancy  child's room     fruits      Fruit Walls   1.0.0
# 3        bathroom      facility       None       Tile Walls   1.0.0
# 4            shop     expensive       None    Special Walls   1.0.0
# ..            ...           ...        ...              ...     ...
# 242  child's room         fancy       None        Toy Walls   1.0.0
# 243         fancy  child's room       None  Dollhouse Walls   1.0.0
# 244  child's room   living room       None     Simple Walls   1.0.0
# 245         fancy  child's room       None     Stucco Walls   1.0.0
# 246         fancy  child's room       None     Stripe Walls   1.0.0
#
#                    Filename Internal ID    Unique Entry ID
# 0     RoomTexWallAbstract00        4873  FpdbDr4PMe5WdEZkA
# 1        RoomTexWallEgypt00        4936  Y2pykQMhqbEoGGa62
# 2        RoomTexWallApple00        4916  roJZFWataeLQK6vqa
# 3         RoomTexWallTile01        4930  6NXvjsdpxJLbd96RM
# 4         RoomSpWallGlass00        5482  TzS5oe6a7KyBezmLS
# ..                      ...         ...                ...
# 242        RoomTexWallToy03        6865  mraytANoYBQvA8qAk
# 243  RoomTexWallDollhouse02        7276  ysEdh2vpCpg5qBcNg
# 244     RoomTexWallSimple01        4867  7sSXFNqcYgPMcGY8k
# 245     RoomTexWallStucco00        4808  TySAA4kKqyvGGeZ5C
# 246     RoomTexWallStripe04        4946  N6sef3YhY973LDgdR
#
# [247 rows x 26 columns]

# %%
# wallpaper_df.insert(0,'Wallpaper_ID',range(1,248),True)

# %%
vlookup_result = pd.merge(vlgr_df,wallpaper_df,on='Wallpaper',how='inner')

# %%
vlookup_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 391 entries, 0 to 390
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               391 non-null    object
#  1   Species            391 non-null    object
#  2   Gender             391 non-null    object
#  3   Personality        391 non-null    object
#  4   Hobby              391 non-null    object
#  5   Birthday           391 non-null    object
#  6   Catchphrase        391 non-null    object
#  7   Favorite Song      391 non-null    object
#  8   Style 1            391 non-null    object
#  9   Style 2            391 non-null    object
#  10  Color 1_x          391 non-null    object
#  11  Color 2_x          391 non-null    object
#  12  Wallpaper          391 non-null    object
#  13  Flooring           391 non-null    object
#  14  Furniture List     391 non-null    object
#  15  Filename_x         391 non-null    object
#  16  Unique Entry ID_x  391 non-null    object
#  17  VFX                391 non-null    object
#  18  VFX Type           59 non-null     object
#  19  DIY                391 non-null    object
#  20  Buy                391 non-null    object
#  21  Sell               391 non-null    float64
#  22  Color 1_y          391 non-null    object
#  23  Color 2_y          391 non-null    object
#  24  Miles Price        0 non-null      float64
#  25  Source             391 non-null    object
#  26  Source Notes       0 non-null      float64
#  27  Catalog            391 non-null    object
#  28  Window Type        391 non-null    object
#  29  Window Color       188 non-null    object
#  30  Pane Type          188 non-null    object
#  31  Curtain Type       391 non-null    object
#  32  Curtain Color      119 non-null    object
#  33  Ceiling Type       391 non-null    object
#  34  HHA Concept 1      391 non-null    object
#  35  HHA Concept 2      391 non-null    object
#  36  HHA Series         391 non-null    object
#  37  Tag                391 non-null    object
#  38  Version            391 non-null    object
#  39  Filename_y         391 non-null    object
#  40  Internal ID        391 non-null    int64
#  41  Unique Entry ID_y  391 non-null    object
# dtypes: float64(3), int64(1), object(38)
# memory usage: 131.4+ KB

# %%
vlookup_result
# Out:
#          Name   Species  Gender Personality      Hobby Birthday Catchphrase  \
# 0     Admiral      Bird    Male      Cranky     Nature   27-Jan     aye aye
# 1     Hornsby     Rhino    Male        Lazy     Nature   20-Mar   schnozzle
# 2    Wart Jr.      Frog    Male      Cranky  Education   21-Aug  grr-ribbit
# 3     Agent S  Squirrel  Female       Peppy    Fitness    2-Jul    sidekick
# 4          Al   Gorilla    Male        Lazy    Fitness   18-Oct     ayyyeee
# ..        ...       ...     ...         ...        ...      ...         ...
# 386    Tipper       Cow  Female      Snooty    Fashion   25-Aug       pushy
# 387      Tutu      Bear  Female       Peppy    Fashion   15-Sep    twinkles
# 388    Tybalt     Tiger    Male        Jock       Play   19-Aug     grrrRAH
# 389     Weber      Duck    Male        Lazy     Nature   30-Jun        quaa
# 390   Whitney      Wolf  Female      Snooty    Fashion   17-Sep      snappy
#
#       Favorite Song   Style 1 Style 2  ...  Curtain Color Ceiling Type  \
# 0        Steep Hill      Cool    Cool  ...            NaN         Wood
# 1       K.K. Lament    Simple  Simple  ...            NaN         Wood
# 2        Steep Hill    Simple  Simple  ...            NaN         Wood
# 3     Go K.K. Rider    Active  Simple  ...  White Plastic        Stone
# 4     Go K.K. Rider    Active  Active  ...  White Plastic        Stone
# ..              ...       ...     ...  ...            ...          ...
# 386    Soulful K.K.  Gorgeous    Cute  ...            NaN        Stone
# 387  Bubblegum K.K.      Cute  Simple  ...          White        Cloth
# 388     K.K. Groove    Active  Simple  ...            NaN        Stone
# 389     K.K. Fusion      Cool  Simple  ...            NaN         Tile
# 390       K.K. Soul   Elegant    Cool  ...          White         Wood
#
#     HHA Concept 1 HHA Concept 2 HHA Series               Tag Version  \
# 0          horror          None       None       Stone Walls   1.0.0
# 1          horror          None       None       Stone Walls   1.0.0
# 2          horror          None       None       Stone Walls   1.0.0
# 3          garage      facility       None       Stone Walls   1.0.0
# 4          garage      facility       None       Stone Walls   1.0.0
# ..            ...           ...        ...               ...     ...
# 386      facility         music       None        Hall Walls   1.0.0
# 387         fancy  child's room       None      Stripe Walls   1.0.0
# 388         fancy   living room       None      Stucco Walls   1.0.0
# 389         music      facility       None    Pegboard Walls   1.0.0
# 390   living room          shop       None  Flower Pop Walls   1.0.0
#
#                  Filename_y Internal ID  Unique Entry ID_y
# 0      RoomTexWallOldSoil00        4856  LCJDGnfwuHqkgfxJB
# 1      RoomTexWallOldSoil00        4856  LCJDGnfwuHqkgfxJB
# 2      RoomTexWallOldSoil00        4856  LCJDGnfwuHqkgfxJB
# 3     RoomTexWallConcrete00        4890  jmixjxLNuH9jRQhyr
# 4     RoomTexWallConcrete00        4890  jmixjxLNuH9jRQhyr
# ..                      ...         ...                ...
# 386       RoomTexWallHall02        6861  HZoM3iHpKrQPBK2Gh
# 387     RoomTexWallStripe01        4943  Pwd2z87xxFm52tA28
# 388     RoomTexWallStucco03        4811  Pdr9WyCDQ9MBgG2qf
# 389   RoomTexWallPegboard02        4922  7fMiJATy4fWP4DpoC
# 390  RoomTexWallFlowerPop00        4848  p65nAJPAzQRgrjmDk
#
# [391 rows x 42 columns]

# %%
vlookup_result[['Name','Wallpaper','Buy','Source']]

# Verifying with a vlookup made .xlsx document: It works!!
# Out:
#          Name                    Wallpaper   Buy         Source
# 0     Admiral               dirt-clod wall   200  Nook's Cranny
# 1     Hornsby               dirt-clod wall   200  Nook's Cranny
# 2    Wart Jr.               dirt-clod wall   200  Nook's Cranny
# 3     Agent S                concrete wall   940  Nook's Cranny
# 4          Al                concrete wall   940  Nook's Cranny
# ..        ...                          ...   ...            ...
# 386    Tipper           white hallway wall  2000  Nook's Cranny
# 387      Tutu            pink-striped wall  1520  Nook's Cranny
# 388    Tybalt              blue-paint wall  1600  Nook's Cranny
# 389     Weber  black perforated-board wall  1180  Nook's Cranny
# 390   Whitney          blue intricate wall  1570  Nook's Cranny
#
# [391 rows x 4 columns]

# %%
#Renaming columns to avoid confusion when merging vlookup_result with the flooring_df

# %%
vlookup_result=vlookup_result.rename(columns = {'Source':'Source_Wallpaper','Buy':'Buy_Wallpaper','Sell':"Sell_Wallpaper"})

# %%
vlookup_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 391 entries, 0 to 390
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               391 non-null    object
#  1   Species            391 non-null    object
#  2   Gender             391 non-null    object
#  3   Personality        391 non-null    object
#  4   Hobby              391 non-null    object
#  5   Birthday           391 non-null    object
#  6   Catchphrase        391 non-null    object
#  7   Favorite Song      391 non-null    object
#  8   Style 1            391 non-null    object
#  9   Style 2            391 non-null    object
#  10  Color 1_x          391 non-null    object
#  11  Color 2_x          391 non-null    object
#  12  Wallpaper          391 non-null    object
#  13  Flooring           391 non-null    object
#  14  Furniture List     391 non-null    object
#  15  Filename_x         391 non-null    object
#  16  Unique Entry ID_x  391 non-null    object
#  17  VFX                391 non-null    object
#  18  VFX Type           59 non-null     object
#  19  DIY                391 non-null    object
#  20  Buy_Wallpaper      391 non-null    object
#  21  Sell_Wallpaper     391 non-null    float64
#  22  Color 1_y          391 non-null    object
#  23  Color 2_y          391 non-null    object
#  24  Miles Price        0 non-null      float64
#  25  Source_Wallpaper   391 non-null    object
#  26  Source Notes       0 non-null      float64
#  27  Catalog            391 non-null    object
#  28  Window Type        391 non-null    object
#  29  Window Color       188 non-null    object
#  30  Pane Type          188 non-null    object
#  31  Curtain Type       391 non-null    object
#  32  Curtain Color      119 non-null    object
#  33  Ceiling Type       391 non-null    object
#  34  HHA Concept 1      391 non-null    object
#  35  HHA Concept 2      391 non-null    object
#  36  HHA Series         391 non-null    object
#  37  Tag                391 non-null    object
#  38  Version            391 non-null    object
#  39  Filename_y         391 non-null    object
#  40  Internal ID        391 non-null    int64
#  41  Unique Entry ID_y  391 non-null    object
# dtypes: float64(3), int64(1), object(38)
# memory usage: 131.4+ KB

# %%
#Renaming columns to avoid confusion when merging vlookup_result with the flooring_df

# %%
flooring_df=flooring_df.rename(columns={'Source':'Source_Floor'})

# %%
flooring_df=flooring_df.rename(columns={'Buy':'Buy_Floor','Sell':'Sell_Floor'})

# %%
flooring_df.info() 
# Helps to review if anything needs renaming
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Flooring         176 non-null    object
#  1   VFX              173 non-null    object
#  2   DIY              176 non-null    object
#  3   Buy_Floor        176 non-null    object
#  4   Sell_Floor       176 non-null    int64
#  5   Color 1          176 non-null    object
#  6   Color 2          176 non-null    object
#  7   Miles Price      1 non-null      float64
#  8   Source_Floor     176 non-null    object
#  9   Source Notes     0 non-null      float64
#  10  Version          176 non-null    object
#  11  HHA Concept 1    176 non-null    object
#  12  HHA Concept 2    176 non-null    object
#  13  HHA Series       176 non-null    object
#  14  Tag              176 non-null    object
#  15  Catalog          176 non-null    object
#  16  Filename         176 non-null    object
#  17  Internal ID      176 non-null    int64
#  18  Unique Entry ID  176 non-null    object
# dtypes: float64(2), int64(2), object(15)
# memory usage: 26.2+ KB

# %%
 Combined_df = pd.merge(vlookup_result,flooring_df,on='Flooring',how='inner')

# %%
Combined_df.info()

#verifying if all merged data are present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 391 entries, 0 to 390
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               391 non-null    object
#  1   Species            391 non-null    object
#  2   Gender             391 non-null    object
#  3   Personality        391 non-null    object
#  4   Hobby              391 non-null    object
#  5   Birthday           391 non-null    object
#  6   Catchphrase        391 non-null    object
#  7   Favorite Song      391 non-null    object
#  8   Style 1            391 non-null    object
#  9   Style 2            391 non-null    object
#  10  Color 1_x          391 non-null    object
#  11  Color 2_x          391 non-null    object
#  12  Wallpaper          391 non-null    object
#  13  Flooring           391 non-null    object
#  14  Furniture List     391 non-null    object
#  15  Filename_x         391 non-null    object
#  16  Unique Entry ID_x  391 non-null    object
#  17  VFX_x              391 non-null    object
#  18  VFX Type           59 non-null     object
#  19  DIY_x              391 non-null    object
#  20  Buy_Wallpaper      391 non-null    object
#  21  Sell_Wallpaper     391 non-null    float64
#  22  Color 1_y          391 non-null    object
#  23  Color 2_y          391 non-null    object
#  24  Miles Price_x      0 non-null      float64
#  25  Source_Wallpaper   391 non-null    object
#  26  Source Notes_x     0 non-null      float64
#  27  Catalog_x          391 non-null    object
#  28  Window Type        391 non-null    object
#  29  Window Color       188 non-null    object
#  30  Pane Type          188 non-null    object
#  31  Curtain Type       391 non-null    object
#  32  Curtain Color      119 non-null    object
#  33  Ceiling Type       391 non-null    object
#  34  HHA Concept 1_x    391 non-null    object
#  35  HHA Concept 2_x    391 non-null    object
#  36  HHA Series_x       391 non-null    object
#  37  Tag_x              391 non-null    object
#  38  Version_x          391 non-null    object
#  39  Filename_y         391 non-null    object
#  40  Internal ID_x      391 non-null    int64
#  41  Unique Entry ID_y  391 non-null    object
#  42  VFX_y              391 non-null    object
#  43  DIY_y              391 non-null    object
#  44  Buy_Floor          391 non-null    object
#  45  Sell_Floor         391 non-null    int64
#  46  Color 1            391 non-null    object
#  47  Color 2            391 non-null    object
#  48  Miles Price_y      0 non-null      float64
#  49  Source_Floor       391 non-null    object
#  50  Source Notes_y     0 non-null      float64
#  51  Version_y          391 non-null    object
#  52  HHA Concept 1_y    391 non-null    object
#  53  HHA Concept 2_y    391 non-null    object
#  54  HHA Series_y       391 non-null    object
#  55  Tag_y              391 non-null    object
#  56  Catalog_y          391 non-null    object
#  57  Filename           391 non-null    object
#  58  Internal ID_y      391 non-null    int64
#  59  Unique Entry ID    391 non-null    object
# dtypes: float64(5), int64(3), object(52)
# memory usage: 186.3+ KB

# %%
Combined_df
# Out:
#          Name   Species  Gender Personality      Hobby Birthday Catchphrase  \
# 0     Admiral      Bird    Male      Cranky     Nature   27-Jan     aye aye
# 1    Annalisa  Anteater  Female      Normal     Nature    6-Feb     gumdrop
# 2         Ken   Chicken    Male        Smug  Education   23-Dec    no doubt
# 3      Cyrano  Anteater    Male      Cranky  Education    9-Mar     ah-CHOO
# 4      Gladys   Ostrich  Female      Normal  Education   15-Jan     stretch
# ..        ...       ...     ...         ...        ...      ...         ...
# 386    Phoebe   Ostrich  Female  Big Sister    Fitness   22-Apr      sparky
# 387    Ribbot      Frog    Male        Jock    Fitness   13-Feb   zzrrbbitt
# 388  Sprocket   Ostrich    Male        Jock      Music    1-Dec        zort
# 389  Sterling     Eagle    Male        Jock    Fitness   11-Dec    skraaaaw
# 390  Stitches       Cub    Male        Lazy       Play   10-Feb    stuffin'
#
#       Favorite Song   Style 1   Style 2  ... Source Notes_y Version_y  \
# 0        Steep Hill      Cool      Cool  ...            NaN     1.0.0
# 1         King K.K.   Elegant  Gorgeous  ...            NaN     1.0.0
# 2        K.K. Rally      Cool    Simple  ...            NaN     1.0.0
# 3       K.K. Lament      Cool    Active  ...            NaN     1.0.0
# 4         K.K. Folk   Elegant      Cute  ...            NaN     1.0.0
# ..              ...       ...       ...  ...            ...       ...
# 386   K.K. Flamenco  Gorgeous      Cool  ...            NaN     1.0.0
# 387  K.K. Technopop    Simple    Active  ...            NaN     1.0.0
# 388      K.K. Metal    Simple    Active  ...            NaN     1.0.0
# 389      K.K. Dirge    Simple   Elegant  ...            NaN     1.0.0
# 390      I Love You    Simple      Cute  ...            NaN     1.0.0
#
#     HHA Concept 1_y HHA Concept 2_y HHA Series_y                     Tag_y  \
# 0         zen-style     living room         None                    Tatami
# 1         zen-style     living room         None                    Tatami
# 2         zen-style     living room         None                    Tatami
# 3         zen-style     living room         None                    Tatami
# 4         zen-style     living room         None                    Tatami
# ..              ...             ...          ...                       ...
# 386          horror            None         None  Special Inorganic Floors
# 387          horror        folk art         None  Special Inorganic Floors
# 388        facility            None         None             Machine Floor
# 389          horror        facility         None              Stone Floors
# 390       expensive            shop         None               Tile Floors
#
#         Catalog_y                     Filename Internal ID_y  \
# 0        For sale         RoomTexFloorTatami00          5039
# 1        For sale         RoomTexFloorTatami00          5039
# 2        For sale         RoomTexFloorTatami00          5039
# 3        For sale         RoomTexFloorTatami00          5039
# 4        For sale         RoomTexFloorTatami00          5039
# ..            ...                          ...           ...
# 386  Not for sale         RoomSpFloorVolcano00          5274
# 387  Not for sale      RoomSpFloorTechnology00          5250
# 388  Not for sale           RoomTexFloorGeek00          5082
# 389  Not for sale       RoomTexFloorBasement00          4797
# 390      For sale  RoomTexFloorPatchworkTile00          4995
#
#        Unique Entry ID
# 0    jdcZQ9LCDoroeYKws
# 1    jdcZQ9LCDoroeYKws
# 2    jdcZQ9LCDoroeYKws
# 3    jdcZQ9LCDoroeYKws
# 4    jdcZQ9LCDoroeYKws
# ..                 ...
# 386  uT9YnwivAEZ938FKB
# 387  eZweMfrfieMDtihv7
# 388  mqiB9cY9EEtRXQoFS
# 389  DgaMSqGEyko87dD3H
# 390  hCAe3badxv5faWwGE
#
# [391 rows x 60 columns]

# %% [markdown]
# ### 4. Begin the Exploration

# %%
Combined_df[['Name','Wallpaper','Buy_Wallpaper','Source_Wallpaper','Flooring','Buy_Floor','Source_Floor']]
# Out:
#          Name              Wallpaper Buy_Wallpaper Source_Wallpaper  \
# 0     Admiral         dirt-clod wall           200    Nook's Cranny
# 1    Annalisa       gold-screen wall           NFS         Crafting
# 2         Ken  standard tearoom wall          1750    Nook's Cranny
# 3      Cyrano           shoji screen          1880    Nook's Cranny
# 4      Gladys           shoji screen          1880    Nook's Cranny
# ..        ...                    ...           ...              ...
# 386    Phoebe      magma-cavern wall          3000          Saharah
# 387    Ribbot     circuit-board wall          3000          Saharah
# 388  Sprocket       future-tech wall          3000          Saharah
# 389  Sterling           dungeon wall          3000          Saharah
# 390  Stitches        blue quilt wall          2150    Nook's Cranny
#
#                     Flooring Buy_Floor   Source_Floor
# 0                     tatami      2200  Nook's Cranny
# 1                     tatami      2200  Nook's Cranny
# 2                     tatami      2200  Nook's Cranny
# 3                     tatami      2200  Nook's Cranny
# 4                     tatami      2200  Nook's Cranny
# ..                       ...       ...            ...
# 386            lava flooring      3000        Saharah
# 387     future-tech flooring      3000        Saharah
# 388   circuit-board flooring      3000        Saharah
# 389        basement flooring       NFS       Crafting
# 390  patchwork-tile flooring      2100  Nook's Cranny
#
# [391 rows x 7 columns]

# %%
Combined_df.Wallpaper.value_counts()

#Most Villagers bought Backyard-Fence wall followed by Concrete wall as their wall paper of choice
# Out:
# backyard-fence wall       13
# concrete wall             11
# arched-window wall         8
# ice wall                   8
# cabin wall                 7
#                           ..
# olive desert-tile wall     1
# screen wall                1
# garbage-heap wall          1
# blue-paint wall            1
# blue quilt wall            1
# Name: Wallpaper, Length: 154, dtype: int64

# %%
Combined_df.Flooring.value_counts()

# Most Villagers bought Backyard Lawns followed by Rosewood flooring as the floorings of choice
# Out:
# backyard lawn                  13
# rosewood flooring              11
# monochromatic tile flooring    11
# wooden-knot flooring           11
# simple white flooring          11
#                                ..
# blue camo flooring              1
# cool vinyl flooring             1
# floral mosaic-tile flooring     1
# giraffe-print flooring          1
# patchwork-tile flooring         1
# Name: Flooring, Length: 128, dtype: int64

# %%
#No joke on my report. I notice every Villager has a unique identified catchprase
# We are gonna use that to create a pivot table along with Gender and Wallpaper
#Find how many bought wallpaper when breaking them down

Combined_pivot_df = pd.pivot_table(Combined_df, index='Gender',values='Catchphrase',columns = 'Wallpaper',aggfunc='count')

# %%
Combined_pivot_df['backyard-fence wall']

# We see that almost equal gender purchases  were made on the backyard-fence wall
# Out:
# Gender
# Female    6.0
# Male      7.0
# Name: backyard-fence wall, dtype: float64

# %%
Combined_pivot_df2= pd.pivot_table(Combined_df, index='Gender',values='Catchphrase',columns = 'Flooring',aggfunc='count')

# %%
Combined_pivot_df2
# Out:
# Flooring  Saharah's desert  arabesque flooring  artsy parquet flooring  \
# Gender
# Female                 NaN                 5.0                     NaN
# Male                   2.0                 1.0                     1.0
#
# Flooring  backyard lawn  bamboo flooring  basement flooring  \
# Gender
# Female              4.0              4.0                NaN
# Male                9.0              3.0                1.0
#
# Flooring  berry-chocolates flooring  birch flooring  \
# Gender
# Female                          2.0             3.0
# Male                            NaN             1.0
#
# Flooring  black iron-parquet flooring  blue camo flooring  ...  \
# Gender                                                     ...
# Female                            1.0                 NaN  ...
# Male                              NaN                 1.0  ...
#
# Flooring  tatami flooring  tiger-print flooring  water flooring  \
# Gender
# Female                2.0                   2.0             NaN
# Male                  NaN                   2.0             1.0
#
# Flooring  white iron-parquet flooring  white mosaic-tile flooring  \
# Gender
# Female                            1.0                         NaN
# Male                              NaN                         1.0
#
# Flooring  white-paint flooring  wildflower meadow  wooden-knot flooring  \
# Gender
# Female                     2.0                2.0                   5.0
# Male                       NaN                NaN                   6.0
#
# Flooring  yellow floral flooring  zebra-print flooring
# Gender
# Female                       4.0                   1.0
# Male                         NaN                   NaN
#
# [2 rows x 128 columns]

# %%
Combined_pivot_df2['backyard lawn']
# We see that more Males than Females bought the backyard lawn
# Out:
# Gender
# Female    4.0
# Male      9.0
# Name: backyard lawn, dtype: float64

# %%
Combined_pivot_df3= pd.pivot_table(Combined_df, index='Source_Wallpaper',values='Catchphrase',columns = 'Wallpaper',aggfunc='count')

# %%
Combined_pivot_df3
# Out:
# Wallpaper         abstract wall  ancient wall  apple wall  aqua tile wall  \
# Source_Wallpaper
# Crafting                    NaN           NaN         1.0             NaN
# Nook's Cranny               2.0           NaN         NaN             1.0
# Saharah                     NaN           3.0         NaN             NaN
#
# Wallpaper         arched-window wall  autumn wall  backyard-fence wall  \
# Source_Wallpaper
# Crafting                         NaN          5.0                  NaN
# Nook's Cranny                    8.0          NaN                  NaN
# Saharah                          NaN          NaN                 13.0
#
# Wallpaper         bamboo wall  bamboo-grove wall  bamboo-screen wall  ...  \
# Source_Wallpaper                                                      ...
# Crafting                  3.0                4.0                 NaN  ...
# Nook's Cranny             NaN                NaN                 1.0  ...
# Saharah                   NaN                NaN                 NaN  ...
#
# Wallpaper         white perforated-board wall  white simple-cloth wall  \
# Source_Wallpaper
# Crafting                                  NaN                      NaN
# Nook's Cranny                             3.0                      2.0
# Saharah                                   NaN                      NaN
#
# Wallpaper         white subway-tile wall  white-brick wall  white-rose wall  \
# Source_Wallpaper
# Crafting                             NaN               NaN              NaN
# Nook's Cranny                        3.0               2.0              2.0
# Saharah                              NaN               NaN              NaN
#
# Wallpaper         wild-wood wall  woodland wall  yellow intricate wall  \
# Source_Wallpaper
# Crafting                     2.0            5.0                    NaN
# Nook's Cranny                NaN            NaN                    4.0
# Saharah                      NaN            NaN                    NaN
#
# Wallpaper         yellow playroom wall  yellow quilt wall
# Source_Wallpaper
# Crafting                           NaN                NaN
# Nook's Cranny                      4.0                1.0
# Saharah                            NaN                NaN
#
# [3 rows x 154 columns]

# %%
Combined_pivot_df3['backyard-fence wall']
# Despite these wall paper purchases came from a competitor. I suggest Tom Nook to offer furniture for that wallpaper. 
# Like a bug zapper, Lawn chair, pink flamingos, garden gnomes,etc.
# Out:
# Source_Wallpaper
# Crafting          NaN
# Nook's Cranny     NaN
# Saharah          13.0
# Name: backyard-fence wall, dtype: float64

# %%
Combined_pivot_df3['concrete wall']
# Out:
# Source_Wallpaper
# Crafting          NaN
# Nook's Cranny    11.0
# Saharah           NaN
# Name: concrete wall, dtype: float64

# %%
Combined_df.groupby('Hobby').Gender.value_counts().plot.barh()
# Out:
# <AxesSubplot:ylabel='Hobby,Gender'>

# %%
Combined_df.pivot_table(index=['Gender','Hobby'],values='Catchphrase',aggfunc='count')
# Out:
#                   Catchphrase
# Gender Hobby
# Female Education           32
#        Fashion             66
#        Fitness             12
#        Music               34
#        Nature              27
#        Play                16
# Male   Education           32
#        Fitness             54
#        Music               30
#        Nature              39
#        Play                49

# %%
species_wallpaper = Combined_df.groupby('Species').count()['Wallpaper'].to_frame().reset_index().sort_values('Wallpaper', ascending = False)

# %%
species_wallpaper
# Out:
#       Species  Wallpaper
# 5         Cat         23
# 29     Rabbit         20
# 32   Squirrel         18
# 14       Frog         18
# 11       Duck         17
# 10        Dog         16
# 8         Cub         16
# 19      Horse         15
# 28        Pig         15
# 24      Mouse         15
# 2        Bear         15
# 31      Sheep         13
# 3        Bird         13
# 27    Penguin         13
# 13   Elephant         11
# 34       Wolf         11
# 9        Deer         10
# 26    Ostrich         10
# 12      Eagle          9
# 6     Chicken          9
# 16    Gorilla          9
# 21      Koala          9
# 23     Monkey          8
# 17    Hamster          8
# 20   Kangaroo          8
# 15       Goat          8
# 22       Lion          7
# 18      Hippo          7
# 1    Anteater          7
# 33      Tiger          7
# 0   Alligator          7
# 30      Rhino          6
# 4        Bull          6
# 7         Cow          4
# 25    Octopus          3

# %%
species_floor = Combined_df.groupby('Species').count()['Flooring'].to_frame().reset_index().sort_values('Flooring', ascending = False)
species_floor
# Out:
#       Species  Flooring
# 5         Cat        23
# 29     Rabbit        20
# 32   Squirrel        18
# 14       Frog        18
# 11       Duck        17
# 10        Dog        16
# 8         Cub        16
# 19      Horse        15
# 28        Pig        15
# 24      Mouse        15
# 2        Bear        15
# 31      Sheep        13
# 3        Bird        13
# 27    Penguin        13
# 13   Elephant        11
# 34       Wolf        11
# 9        Deer        10
# 26    Ostrich        10
# 12      Eagle         9
# 6     Chicken         9
# 16    Gorilla         9
# 21      Koala         9
# 23     Monkey         8
# 17    Hamster         8
# 20   Kangaroo         8
# 15       Goat         8
# 22       Lion         7
# 18      Hippo         7
# 1    Anteater         7
# 33      Tiger         7
# 0   Alligator         7
# 30      Rhino         6
# 4        Bull         6
# 7         Cow         4
# 25    Octopus         3

# %%
filtered_df = Combined_df[Combined_df.Species == 'Cat']

pivot_table = filtered_df.pivot_table(index=['Species','Gender'], values='Catchphrase', aggfunc='count')

pivot_table
# Out:
#                 Catchphrase
# Species Gender
# Cat     Female           14
#         Male              9

# %%
pivot_table.plot(kind='bar')
plt.title("Cat Shoppers")
plt.xlabel('Gender')
plt.ylabel('Number of Shoppers ')
# Out:
# Text(0, 0.5, 'Number of Shoppers ')

# %%
# We now know that Cats are the largest purchasers of wallpaper and Flooring. 
# Do they correlate to purchases of Backyard Wall paper & Backyard Lawns?
# also look at the next top 5

# %%
Shopping_Flooring = Combined_df.pivot_table(index=['Gender','Source_Floor'], values=['Catchphrase'],aggfunc='count')
Shopping_Flooring
# Out:
#                       Catchphrase
# Gender Source_Floor
# Female Crafting                20
#        Nook's Cranny          143
#        Saharah                 24
# Male   Crafting                40
#        Nook's Cranny          110
#        Saharah                 54

# %%
Shopping_Flooring.plot(kind='bar')
plt.title("Shoppers of Floorplans")
plt.xlabel('Gender per Market')
plt.ylabel('Number of Shoppers ')
# Out:
# Text(0, 0.5, 'Number of Shoppers ')

# %%
# We can see that Tom Nook is taking the lead in Floorings sold for both Female and Male shoppers

# %%
Shopping_Wallpaper = Combined_df.pivot_table(index=['Gender','Source_Wallpaper'],values=['Catchphrase'],aggfunc='count')
Shopping_Wallpaper
# Out:
#                          Catchphrase
# Gender Source_Wallpaper
# Female Crafting                   30
#        Nook's Cranny             114
#        Saharah                    43
# Male   Crafting                   63
#        Nook's Cranny              75
#        Saharah                    66

# %%
Shopping_Wallpaper.plot(kind='bar')
plt.title("Shoppers of Wallpaper")
plt.xlabel('Gender per Market')
plt.ylabel('Number of Shoppers ')
# Out:
# Text(0, 0.5, 'Number of Shoppers ')

# %%
# Most female shoppers go to Nook's Cranny. 
# Male shoppers almost equally are divided between crafting their own wall paper, shopping at Nook's Cranny and Saharah

# %% [markdown]
# # Conclusion

# %%
# I have a gut feeling that Tom Nook should purchase furniture 
# that cater towards the ladies and/or Cats that demand the outdoor based wallpaper and flooring. 
# Also make sure the furniture can to a degree satisfy the fashionable lifestyle category
# I will go ahead and transfer the merged documents to Excel followed by PowerBI for further exploration and visualization

# Combined_df.to_excel(r"C:\Users\carlo\OneDrive\Documents\My Data Analytics Projects\Animal Crossing\Animal Crossing Tom Nook Business Project\Combined_Villagers.xlsx", index=False)
